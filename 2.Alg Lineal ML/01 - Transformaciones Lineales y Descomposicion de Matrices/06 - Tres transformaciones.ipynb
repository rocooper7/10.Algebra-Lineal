# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# %run "..\\funciones_auxiliares\\graficarVectores.ipynb"
# %run "..\\funciones_auxiliares\\graficarMatriz.ipynb"

# %%
A = np.array([[3, 7], [5, 2]])

print(A)
# Out:
# [[3 7]
#  [5 2]]

# %%
print('Circulo unitario:')
graficarMatriz(np.array([[1, 0], [0, 1]]))

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.show()

print('Circulo unitario transformado:')
graficarMatriz(A)

plt.xlim(-8, 8)
plt.ylim(-8, 8)
plt.show()
# Out:
# Circulo unitario:
# Circulo unitario transformado:

# %%
U, D, V = np.linalg.svd(A)
print(U)
print(D)
print(V)
# Out:
# [[-0.85065081 -0.52573111]
#  [-0.52573111  0.85065081]]
# [8.71337969 3.32821489]
# [[-0.59455781 -0.80405286]
#  [ 0.80405286 -0.59455781]]

# %%
print('Circulo unitario:')
graficarMatriz(np.array([[1, 0], [0, 1]]))

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.show()

print('Primer Rotacion V:')     #Genera la primera rotación
graficarMatriz(V)

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.show()

print('Escala (D):')          #Agranda el espacio en un sentido y en el otro lo achica
graficarMatriz(np.diag(D).dot(V))

plt.xlim(-9, 9)
plt.ylim(-9, 9)
plt.show()

print('Segunda Rotacion U:')       #Termina de rotarlo y da el mismo efecto de la Matriz A 
graficarMatriz(U.dot(np.diag(D).dot(V)))

plt.xlim(-8, 8)
plt.ylim(-8, 8)
plt.show()
# Out:
# Circulo unitario:
# Primer Rotacion V:
# Escala (D):
# Segunda Rotacion U:

# %%
print('Circulo unitario transformado:')
graficarMatriz(A)

plt.xlim(-8, 8)
plt.ylim(-8, 8)
plt.show()
# Out:
# Circulo unitario transformado:
