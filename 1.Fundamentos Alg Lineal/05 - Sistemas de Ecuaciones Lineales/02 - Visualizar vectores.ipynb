# %%
#%matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
v1 = np.array([2,5])           # Funciones Auxiliares(graficar Vectores)
v2 = np.array([3,2])

# %%
# %run "..\\funciones_auxiliares\graficarVectores.ipynb"

# %%
graficarVectores([v1, v2], ['orange', 'blue'])
plt.xlim(-1, 8)
plt.ylim(-1, 8);
